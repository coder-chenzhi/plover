# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import seaborn as sns

# %%
perf_data_file = r"E:\IDEAWorkspace\autologguards\auto-guard\src\main\py\lrt\PerfSummaryPlot.xlsx"

# %%
hadoop_all_features_ranker = pd.read_excel(perf_data_file, sheet_name="HadoopAllFeatures", index_col=0)
zookeeper_all_features_ranker = pd.read_excel(perf_data_file, sheet_name="ZooKeeperAllFeatures", index_col=0)
hadoop_FREQS_ranker = pd.read_excel(perf_data_file, sheet_name="HadoopFREQS", index_col=0)
zookeeper_FREQS_ranker = pd.read_excel(perf_data_file, sheet_name="ZooKeeperFREQS", index_col=0)
hadoop_baseline = pd.read_excel(perf_data_file, sheet_name="HadoopBaseline", index_col=0)
zookeeper_baseline = pd.read_excel(perf_data_file, sheet_name="ZooKeeperBaseline", index_col=0)

# %%
plt.style.use('ggplot')
plt.rc('font', family='Times New Roman')
fig, axs = plt.subplots(1, 2, figsize=(10, 6))

for index in zookeeper_baseline.index:
    axs[0].plot(["5","10","15","20","25","30"], zookeeper_baseline.loc[index], label=index, linestyle='-')
axs[0].yaxis.set_ticks(np.linspace(0, 1, num=11))
axs[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
axs[0].legend(loc="lower right")
axs[0].tick_params(axis='x', colors='black')
axs[0].tick_params(axis='y', colors='black')
axs[0].set_title('(a) P@K for ZooKeeper', y=-0.16)

for index in hadoop_baseline.index:
    axs[1].plot(["5","10","15","20","25","30"], hadoop_baseline.loc[index], label=index, linestyle='-')
axs[1].yaxis.set_ticks(np.linspace(0, 1, num=11))
axs[1].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
axs[1].legend(loc="lower right")
axs[1].tick_params(axis='x', colors='black')
axs[1].tick_params(axis='y', colors='black')
axs[1].set_title('(b) P@K for Hadoop', y=-0.16)

plt.show()

# %%
plt.style.use('ggplot')
plt.rc('font', family='Times New Roman')
fig, axs = plt.subplots(1, 2, figsize=(10, 6))

for index in zookeeper_all_features_ranker.index:
    axs[0].plot(["5","10","15","20","25","30"], zookeeper_all_features_ranker.loc[index], label=index, linestyle='-')
axs[0].yaxis.set_ticks(np.linspace(0, 1, num=11))
axs[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
axs[0].legend(loc="lower right")
axs[0].tick_params(axis='x', colors='black')
axs[0].tick_params(axis='y', colors='black')
axs[0].set_title('(a) P@K for ZooKeeper', y=-0.16)

for index in hadoop_all_features_ranker.index:
    axs[1].plot(["5","10","15","20","25","30"], hadoop_all_features_ranker.loc[index], label=index, linestyle='-')
axs[1].yaxis.set_ticks(np.linspace(0, 1, num=11))
axs[1].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
axs[1].legend(loc="lower right")
axs[1].tick_params(axis='x', colors='black')
axs[1].tick_params(axis='y', colors='black')
axs[1].set_title('(b) P@K for Hadoop', y=-0.16)

plt.show()

# %%
plt.style.use('ggplot')
plt.rc('font', family='Times New Roman')
fig, axs = plt.subplots(1, 2, figsize=(10, 6))

for index in zookeeper_FREQS_ranker.index:
    axs[0].plot(["5","10","15","20","25","30"], zookeeper_FREQS_ranker.loc[index], label=index, linestyle='-')
axs[0].yaxis.set_ticks(np.linspace(0, 1, num=11))
axs[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
axs[0].legend(loc="lower right")
axs[0].tick_params(axis='x', colors='black')
axs[0].tick_params(axis='y', colors='black')
axs[0].set_title('(a) P@K for ZooKeeper', y=-0.16)

for index in hadoop_FREQS_ranker.index:
    axs[1].plot(["5","10","15","20","25","30"], hadoop_FREQS_ranker.loc[index], label=index, linestyle='-')
axs[1].yaxis.set_ticks(np.linspace(0, 1, num=11))
axs[1].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
axs[1].legend(loc="lower right")
axs[1].tick_params(axis='x', colors='black')
axs[1].tick_params(axis='y', colors='black')
axs[1].set_title('(b) P@K for Hadoop', y=-0.16)

plt.show()

# %%
data = {
    "Cassandra": [1,1,1,1,1,1,2,1,1,1,1,17,33,8,107,2],
    "Hadoop": [1,1,2,3,1,2,21,1,1,1,17,2,23,1,2,1,2,1,2,2,1,1,1,2,2,1,1,1,2,5,1,1,1,1,1,59],
    "HBase": [1,1,2,3,2,3,4,11,2,2,1,2,2,9,3,1,1,1,4,2,1,1,1,1,1,1,1,1,3,3,1,3,1,1,1,2,1,1,1,3,1,1,2,1,1,2,2,65],
    "Hive" : [1,1,1,4,1,1,2,2,1,1,1,1,1,18,1,1,5,1,1,2,2,5,3,11,3,4,1,1,19],
    "ZooKeeper": [1,1,2,2,10,25,1,1]
}

# %%
df = pd.DataFrame({"Projects":[], "Count": []})

# %%
for project in data:
    project_data = data[project]
    for count in project_data:
        df_tmp = pd.DataFrame({"Projects":[project], "Count": [count]}) 
        df = df.append(df_tmp)

# %%
df
# Out:
#      Projects  Count
# 0   Cassandra    1.0
# 0   Cassandra    1.0
# 0   Cassandra    1.0
# 0   Cassandra    1.0
# 0   Cassandra    1.0
# ..        ...    ...
# 0   ZooKeeper    2.0
# 0   ZooKeeper   10.0
# 0   ZooKeeper   25.0
# 0   ZooKeeper    1.0
# 0   ZooKeeper    1.0
#
# [153 rows x 2 columns]

# %%
def create_median_labels(ax, has_fliers):
    lines = ax.get_lines()
    # depending on fliers, toggle between 5 and 6 lines per box
    lines_per_box = 5 + int(has_fliers)
    # iterate directly over all median lines, with an interval of lines_per_box
    # this enables labeling of grouped data without relying on tick positions
    for median_line in lines[4:len(lines):lines_per_box]:
        # get center of median line
        mean_x = sum(median_line._x) / len(median_line._x)
        mean_y = sum(median_line._y) / len(median_line._y)
        # print text to center coordinates
        text = ax.text(mean_x, mean_y, f'{mean_y:.1f}',
                       ha='center', va='center',
                       fontweight='bold', size=10, color='white')
        # create small black border around white text
        # for better readability on multi-colored boxes
        text.set_path_effects([
            path_effects.Stroke(linewidth=3, foreground='black'),
            path_effects.Normal(),
        ])

# %%
#sns.set_style("whitegrid")
plt.style.use('ggplot')
plt.rc('font', family='Times New Roman')
plt.rcParams["figure.figsize"] = (8,6)

# optionally disable fliers
showfliers = True
# plot data and create median labels
box_plot = sns.boxplot(x="Projects", y="Count", width=0.8, data=df, showfliers=showfliers)

# the_table = plt.table(cellText=[["1", "2", "3", "4", "5", "6"],
#                                 ["1", "2", "3", "4", "5", "6"],
#                                 ["1", "11.5", "1", "6", "1", "1"],
#                                 ["1", "2", "3", "4", "5", "6"],
#                                 ["1", "1", "1", "1", "1", "1"]],
#                       rowLabels=["sum", "mean", "median", "max", "min"],
#                       rowLoc='center',
#                       colLoc='center',
#                       loc='top')

create_median_labels(box_plot.axes, showfliers)

box_plot.set_yscale("log")

legend = plt.legend()
plt.setp(legend.get_texts(), color='black')
plt.gca().tick_params(axis='x', colors='black')
plt.gca().tick_params(axis='y', colors='black')
plt.gca().set_xlabel("", color='black')
plt.gca().set_ylabel("Change Size", color='black')
plt.savefig("E:/Stat.pdf",  bbox_inches='tight', dpi=300)
plt.show()
# Out:
# No handles with labels found to put in legend.
